# %%
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scanpy as sp

# %% [markdown]
# # Load data

# %%
adata = sp.read_mtx("../../Datasets/Calderon/GSE190147_scirnaseq_gene_matrix.mtx")

# %%
adata = adata.T

# %%
rows = pd.read_csv("../../Datasets/Calderon/GSE190147_scirnaseq_gene_matrix.rows.txt", delimiter = "\t",header=None)
cols = pd.read_csv("../../Datasets/Calderon/GSE190147_scirnaseq_gene_matrix.columns.txt", delimiter = "\t", usecols=range(7))

# %%
adata.obs = cols
adata.var = rows

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 23932 × 547805

# %% [markdown]
# ## QC

# %%
# Create a plot showing genes detected as a function of UMI counts.
fig, ax = plt.subplots(figsize=(10, 7))

ax.scatter(np.asarray(mtx.sum(axis=1))[:,0], np.asarray(np.sum(mtx>0, axis=1))[:,0], color="green", alpha=0.01)
ax.set_xlabel("UMI Counts")
ax.set_ylabel("Genes Detected")
ax.set_xscale('log')
ax.set_yscale('log')

plt.show()
