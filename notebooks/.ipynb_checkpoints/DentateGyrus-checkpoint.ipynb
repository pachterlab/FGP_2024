# %% [markdown]
# # Introduction

# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Load packages

# %%
# %cd ../RADOM

# Load before numpy to restrict its usage of cores, otherwise it will use all cores when doing @
import os
os.environ["BLAS_NUM_THREADS"] = "1" 
os.environ["OPENBLAS_NUM_THREADS"] = "1" # 

from inference import Trajectory
from plotting import *
# Out:
# /home/mffang/workspace/Poisson-regression/RADOM

# %%
import scanpy as sc
import scvelo as scv
import scipy as sp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def select_genes(U,S,gene_names,mean_min=0.1,var_min=0.1):
    gene_mask = (np.mean(S,axis=0)>0) & (np.mean(U,axis=0)>0) & (np.var(S,axis=0)>0) & (np.var(U,axis=0)>0)
    s = S[:,gene_mask]
    u = U[:,gene_mask]
    gene_names = gene_names[gene_mask]
    cov = np.cov(u,s,rowvar=False)
    s_mean = np.mean(s,axis=0)
    u_mean = np.mean(u,axis=0)
    X_mean = np.append(u_mean,s_mean)
    p = s.shape[1]
    rho = cov/X_mean[:,None]/X_mean[None,:]
    rho_s = rho[p:,p:]
    rho_u = rho[:p,:p]
    rho_us = rho[:p,p:]
    s = (np.sum(rho_us)-np.sum(np.diag(rho_us)))/(p-1)/p
    genes_mask = (s_mean>mean_min) & (u_mean>mean_min) & (np.abs(np.diag(rho_us)-s)>var_min)
    return gene_names[genes_mask]

# %% [markdown]
# ## Load data

# %%
#!wget --directory-prefix=../data/ http://pklab.med.harvard.edu/velocyto/DentateGyrus/DentateGyrus.loom

adata = sc.read('../data/DentateGyrus.loom')
adata.var_names_make_unique
adata
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# AnnData object with n_obs × n_vars = 18213 × 27998
#     obs: 'Age', 'Cell_Conc', 'ChipID', 'ClusterName', 'Clusters', 'Comments', 'Date_Captured', 'DonorID', 'Label', 'NGI_PlateWell', 'Num_Pooled_Animals', 'PCR_Cycles', 'Plug_Date', 'Project', 'SampleID', 'SampleOK', 'Sample_Index', 'Seq_Comment', 'Seq_Lib_Date', 'Seq_Lib_Ok', 'Serial_Number', 'Sex', 'Species', 'Strain', 'TSNE1', 'TSNE2', 'Target_Num_Cells', 'Tissue', 'Transcriptome', 'cDNA_Lib_Ok', 'ngperul_cDNA'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
adata.obsm['X_tsne'] = np.append(adata.obs['TSNE1'][:,None],adata.obs['TSNE2'][:,None],axis=1)
sc.pl.tsne(adata,color=['ClusterName','Age'],alpha=0.3);
# Out:
# ... storing 'Age' as categorical
# ... storing 'Cell_Conc' as categorical
# ... storing 'ChipID' as categorical
# ... storing 'ClusterName' as categorical
# ... storing 'Comments' as categorical
# ... storing 'Date_Captured' as categorical
# ... storing 'DonorID' as categorical
# ... storing 'Label' as categorical
# ... storing 'NGI_PlateWell' as categorical
# ... storing 'Num_Pooled_Animals' as categorical
# ... storing 'PCR_Cycles' as categorical
# ... storing 'Plug_Date' as categorical
# ... storing 'Project' as categorical
# ... storing 'SampleID' as categorical
# ... storing 'SampleOK' as categorical
# ... storing 'Sample_Index' as categorical
# ... storing 'Seq_Comment' as categorical
# ... storing 'Seq_Lib_Date' as categorical
# ... storing 'Seq_Lib_Ok' as categorical
# ... storing 'Serial_Number' as categorical
# ... storing 'Sex' as categorical
# ... storing 'Species' as categorical
# ... storing 'Strain' as categorical
# ... storing 'Target_Num_Cells' as categorical
# ... storing 'Tissue' as categorical
# ... storing 'Transcriptome' as categorical
# ... storing 'cDNA_Lib_Ok' as categorical
# ... storing 'ngperul_cDNA' as categorical
# ... storing 'Chromosome' as categorical
# ... storing 'Strand' as categorical

# %% [markdown]
# **Check count numbers**

# %%
U_mean = adata.layers["unspliced"].toarray().mean(axis=0)
S_mean = adata.layers["spliced"].toarray().mean(axis=0)

# %%
plt.loglog(U_mean, S_mean,'.');

# %% [markdown]
# # Nbl2 -> Granule and CA

# %%
cell_types = ['Nbl2','CA','ImmGranule1']
for celltype in cell_types:
    print(celltype, np.sum(adata.obs['ClusterName'].isin([celltype])))
# Out:
# Nbl2 1003
# CA 2298
# ImmGranule1 2460

# %%
sc.pl.tsne(data,color=['ClusterName','Age'],alpha=0.5)

# %%
cell_mask = (adata.obs['ClusterName'].isin(cell_types)) & (adata.obs['Age'].isin(['P0']))
data = adata[cell_mask]
data.var_names_make_unique
data.shape
# Out:
# (3616, 27998)

# %% [markdown]
# ## Scanpy genes

# %%
marker_genes = ['Neurod6', 'Igfbpl1','Prox1', 'SOX2','Stmn2','Eomes']

# %%
sc.pp.highly_variable_genes(data,n_top_genes=100,flavor='seurat_v3')
fitted_genes_mask = data.var["highly_variable"] \
            & (data.layers["unspliced"].toarray().mean(axis=0)> 0.01) \
            & (data.layers["spliced"].toarray().mean(axis=0)> 0.01) \
            & (np.abs(np.log10(data.layers["unspliced"].toarray().mean(axis=0)/data.layers["spliced"].toarray().mean(axis=0)))<=2)
#fitted_genes_mask = fitted_genes_mask | data.var_names.isin(marker_genes)
fitted_genes = data.var_names[fitted_genes_mask]

X=np.zeros((data.shape[0],np.sum(fitted_genes_mask),2))
X[:,:,0]=data.layers['unspliced'].toarray()[:,fitted_genes_mask]
X[:,:,1]=data.layers['spliced'].toarray()[:,fitted_genes_mask]
X.shape
# Out:
# (3616, 38, 2)

# %%
plot_mask = fitted_genes.isin(marker_genes)
plot_idx = np.arange(len(fitted_genes))[plot_mask]
print(fitted_genes[plot_mask])
# Out:
# Index(['Prox1', 'Stmn2', 'Neurod6'], dtype='object')

# %% [markdown]
# ### Cluster

# %%
lc = len(cell_types)
m=100
t_grids=np.linspace(0,1,m)
Q0 = np.ones((data.n_obs,2,m))
for i,celltype in enumerate(cell_types):
    print(celltype)
    idx = data.obs['ClusterName'].isin([celltype])
    if i == 0:
        Q0[idx,:,:m//2] += 1
    elif i==1:
        Q0[idx,0,m//2:] += 1
    else:
        Q0[idx,1,m//2:] += 1
    
Q0=Q0/Q0.sum(axis=(1,2),keepdims=True)
#plt.scatter(np.sum(t_grids[None,:]*weight0,axis=1),s,c=colors20[np.mod(clusters, 20)]);
plt.imshow(Q0[:,0],aspect="auto");
# Out:
# Nbl2
# CA
# ImmGranule1

# %%
topo = np.array([[0],[1]])
tau = (0,1) 
traj = Trajectory(topo, tau, model="two_species",verbose=1)
traj = traj.fit(X, Q=Q0, epoch=100, parallel=True,n_threads=2)
traj.compute_AIC(X)
# Out:
# run method fit_warm_start
#  20%|██        | 20/100 [00:12<00:48,  1.64it/s]
# -591982.8181107766

# %%
data.obs["t1"]=traj.Q[:,0]@traj.t
data.obs["t2"]=traj.Q[:,1]@traj.t
sc.pl.tsne(data,color=["t1","t2"],alpha=0.5)

# %%
plot_t(traj.Q,order_cells=True)
# Out:
# <AxesSubplot:>

# %%
plot_phase(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
plot_y(traj,idx=plot_idx,gene_name=fitted_genes,cell_colors=data.obs['Clusters'])

# %% [markdown]
# ### Random Init

# %%
for seed in range(2019,2025):
    traj = Trajectory(topo, tau, model="two_species",verbose=0)
    traj = traj.fit(X, n_init=3, perm_theta=True, epoch=100, parallel=True, n_threads=4,seed=seed)

    data.obs["t1"]=traj.Q[:,0]@traj.t
    data.obs["t2"]=traj.Q[:,1]@traj.t
    sc.pl.tsne(data,color=["t1","t2"],alpha=0.5)

# %%
traj = Trajectory(topo, tau, model="two_species",verbose=0)
traj = traj.fit(X, n_init=10, epoch=100, parallel=True, n_threads=4,seed=2024)

data.obs["t1"]=traj.Q[:,0]@traj.t
data.obs["t2"]=traj.Q[:,1]@traj.t
sc.pl.tsne(data,color=["t1","t2"],alpha=0.5)
# Out:
# run method fit_multi_init
# trial 1
#  33%|███▎      | 33/100 [00:17<00:34,  1.92it/s]
# trial 2
#  34%|███▍      | 34/100 [00:17<00:33,  1.97it/s]
# trial 3
#  15%|█▌        | 15/100 [00:08<00:48,  1.76it/s]
# trial 4
#  26%|██▌       | 26/100 [00:12<00:36,  2.03it/s]
# trial 5
#  45%|████▌     | 45/100 [00:23<00:28,  1.95it/s]
# trial 6
#  25%|██▌       | 25/100 [00:13<00:40,  1.84it/s]
# trial 7
#  27%|██▋       | 27/100 [00:13<00:37,  1.96it/s]
# trial 8
#  27%|██▋       | 27/100 [00:13<00:37,  1.96it/s]
# trial 9
#  59%|█████▉    | 59/100 [00:29<00:20,  1.98it/s]
# trial 10
#  27%|██▋       | 27/100 [00:13<00:36,  2.00it/s]

# %%
plot_phase(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
plot_y(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
diff_genes_idx = np.where(np.abs(traj.theta[:,-3] - traj.theta[:,0]) > 10)[0]
plot_phase(traj,idx=diff_genes_idx,gene_name=fitted_genes)

# %%
plt.plot(traj.theta[:,[-3,0]].T,'-',color='grey');
plt.plot(traj.theta[diff_genes_idx][:,[-3,0]].T,'-',color='r');

# %%
topo = np.array([[0]])
tau = (0,1) 
traj = Trajectory(topo, tau, model="two_species_ss",verbose=1)
traj = traj.fit(X,epoch=100,n_init=10,perm_theta=False,parallel=True,n_threads=2)
traj.compute_AIC(X)
# Out:
# run method fit_multi_init
# trial 1
#  51%|█████     | 51/100 [01:08<01:05,  1.34s/it]
# trial 2
#  33%|███▎      | 33/100 [00:42<01:26,  1.30s/it]
# trial 3
#  25%|██▌       | 25/100 [00:32<01:37,  1.30s/it]
# trial 4
#  52%|█████▏    | 52/100 [01:01<00:57,  1.19s/it]
# trial 5
#  55%|█████▌    | 55/100 [00:58<00:47,  1.06s/it]
# trial 6
#  33%|███▎      | 33/100 [00:41<01:23,  1.25s/it]
# trial 7
#  49%|████▉     | 49/100 [01:06<01:08,  1.35s/it]
# trial 8
#  70%|███████   | 70/100 [01:14<00:31,  1.06s/it]
# trial 9
#  71%|███████   | 71/100 [01:19<00:32,  1.12s/it]
# trial 10
#  63%|██████▎   | 63/100 [01:10<00:41,  1.12s/it]
# -4224919.939745667

# %%
plt.plot([traj.elbos[i][-1] for i in range(len(traj.elbos))],'.')

# %%
plot_t(traj.Q)

# %%
plt.plot(traj.Q.sum(axis=(0,1)));

# %%
data.obs["t"]=traj.Q[:,0]@traj.t
sc.pl.tsne(data,color=["t",'ClusterName'])

# %%
plot_phase(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
plot_y(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
diff_genes_idx = np.where(np.abs(traj.theta[:,-3] - traj.theta[:,0]) > 10)[0]
plot_phase(traj,idx=diff_genes_idx,gene_name=fitted_genes)

# %%
topo = np.array([[0]])
tau = (0,1) 
traj = Trajectory(topo, tau, model="two_species",verbose=1)
traj = traj.fit(X,epoch=100,parallel=True,n_threads=4)
traj.compute_AIC(X)
# Out:
# run method fit_multi_init
# trial 1
#  47%|████▋     | 47/100 [00:22<00:25,  2.11it/s]
#  58%|█████▊    | 58/100 [00:30<00:21,  1.91it/s]
# trial 2
#  40%|████      | 40/100 [00:19<00:29,  2.01it/s]
#  88%|████████▊ | 88/100 [00:43<00:05,  2.00it/s]
# trial 3
#  50%|█████     | 50/100 [00:23<00:23,  2.16it/s]
#  33%|███▎      | 33/100 [00:15<00:32,  2.08it/s]
# -4080437.2786823967

# %%
data.obs["t"]=traj.Q[:,0]@traj.t
sc.pl.tsne(data,color=["t",'ClusterName'])

# %%
plot_phase(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
plot_y(traj,idx=plot_idx,gene_name=fitted_genes)

# %% [markdown]
# ## correlated U and S genes

# %%
U = data.layers["unspliced"].toarray()
S = data.layers["spliced"].toarray()
gene_list = select_genes(U,S,data.var_names,mean_min=0.5,var_min=0.5)
len(gene_list)
# Out:
# 17

# %%
fitted_genes_mask = data.var_names.isin(gene_list) | data.var_names.isin(marker_genes)
fitted_genes = data.var_names[fitted_genes_mask]

X=np.zeros((data.shape[0],np.sum(fitted_genes_mask),2))
X[:,:,0]=data.layers['unspliced'].toarray()[:,fitted_genes_mask]
X[:,:,1]=data.layers['spliced'].toarray()[:,fitted_genes_mask]
X.shape
# Out:
# (2276, 23, 2)

# %%
plot_mask = fitted_genes.isin(marker_genes)
plot_idx = np.arange(len(fitted_genes))[plot_mask]
print(fitted_genes[plot_mask])
# Out:
# Index(['Prox1', 'Etv1', 'Neurod1', 'Igfbpl1', 'Nfia', 'Zic1'], dtype='object')

# %% [markdown]
# ### Uniform prior

# %%
topo = np.array([[0,1]])
tau = (0,1,2) 
traj = Trajectory(topo, tau, model="two_species_ss",verbose=1)
traj = traj.fit(X,epoch=10,parallel=True,n_threads=4)
traj.compute_AIC(X)
# Out:
# run method fit_multi_init
# trial 1
# 100%|██████████| 10/10 [00:03<00:00,  3.25it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.73it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.61it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.73it/s]
# 100%|██████████| 10/10 [00:03<00:00,  3.22it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.80it/s]
# trial 2
# 100%|██████████| 10/10 [00:02<00:00,  3.36it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.73it/s]
# 100%|██████████| 10/10 [00:03<00:00,  3.21it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.67it/s]
# 100%|██████████| 10/10 [00:03<00:00,  3.28it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.61it/s]
# trial 3
# 100%|██████████| 10/10 [00:02<00:00,  3.39it/s]
# 100%|██████████| 10/10 [00:03<00:00,  3.18it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.46it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.37it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.62it/s]
#  80%|████████  | 8/10 [00:02<00:00,  3.52it/s]
# -151379.08928884575

# %%
data.obs["t"]=traj.Q[:,0]@traj.t
sc.pl.tsne(data,color=["t",'ClusterName'])
# Out:
# Trying to set attribute `.obs` of view, copying.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
plot_phase(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
topo = np.array([[0]])
tau = (0,1) 
traj = Trajectory(topo, tau, model="two_species_ss",verbose=1)
traj = traj.fit(X,epoch=100,parallel=True,n_threads=4)
traj.compute_AIC(X)

# %%
data.obs["t"]=traj.Q[:,0]@traj.t
sc.pl.tsne(data,color=["t",'ClusterName'])

# %%
plot_phase(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
plot_y(traj,idx=plot_idx,gene_name=fitted_genes)

# %% [markdown]
# ### Ununiform prior

# %%
prior = np.ones((X.shape[0],1,100))
prior[:,0,0] =  21
prior /= np.sum(prior,axis=(1,2),keepdims=True)

# %%
plt.imshow(prior[:,0],aspect="auto")

# %%
prior[0,0]

# %%
topo = np.array([[0]])
tau = (0,1) 
traj = Trajectory(topo, tau, model="two_species_ss",verbose=1)
traj = traj.fit(X,prior=prior,epoch=100,parallel=True,n_threads=4)
traj.compute_AIC(X)

# %%
plot_t(traj.Q)

# %%
data.obs["t"]=traj.Q[:,0]@traj.t
sc.pl.tsne(data,color=["t",'ClusterName'])

# %%
plot_phase(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
plot_y(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
topo = np.array([[0]])
tau=(0,1)
traj = Trajectory(topo, tau, model="two_species", verbose=1)
traj = traj.fit(X,prior=prior,epoch=100,tol=1e-10,parallel=True,n_threads=10)
traj.compute_AIC(X)

# %%
data.obs["t"]=traj.Q[:,0]@traj.t
sc.pl.tsne(data,color=["t",'ClusterName'])

# %%
plot_phase(traj,idx=plot_idx,gene_name = fitted_genes)

# %%
plot_phase(traj,gene_name = fitted_genes)
