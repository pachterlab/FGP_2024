# %%
# %cd ../RADOM

# Load before numpy to restrict its usage of cores, otherwise it will use all cores when doing @
import os
os.environ["BLAS_NUM_THREADS"] = "1" 
os.environ["OPENBLAS_NUM_THREADS"] = "1" # 

from inference import Trajectory
from plotting import *
# Out:
# /home/mffang/workspace/Poisson-regression/RADOM

# %%
import scanpy as sc
import scvelo as scv
import scipy as sp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def select_genes(U,S,gene_names,mean_min=0.1,var_min=1):
    gene_mask = (np.mean(S,axis=0)>0) & (np.mean(U,axis=0)>0) & (np.var(S,axis=0)>0) & (np.var(U,axis=0)>0)
    s = S[:,gene_mask]
    u = U[:,gene_mask]
    gene_names = gene_names[gene_mask]
    cov = np.cov(u,s,rowvar=False)
    s_mean = np.mean(s,axis=0)
    u_mean = np.mean(u,axis=0)
    X_mean = np.append(u_mean,s_mean)
    p = s.shape[1]
    rho = cov/X_mean[:,None]/X_mean[None,:]
    rho_s = rho[p:,p:]
    rho_u = rho[:p,:p]
    rho_us = rho[:p,p:]
    s = (np.sum(rho_us)-np.sum(np.diag(rho_us)))/(p-1)/p
    genes_mask = (s_mean>mean_min) & (u_mean>mean_min) & (np.abs(np.diag(rho_us)-s)>var_min)
    return gene_names[genes_mask]

# %%
adata = sc.read('../data/sperm_pb.loom')
adata.var_names_make_unique
adata
# Out:
# AnnData object with n_obs × n_vars = 3000 × 18255
#     layers: 'matrix', 'spliced', 'unspliced'

# %%
U = adata.layers['unspliced'].toarray()
S = adata.layers['spliced'].toarray()

# %%
plt.loglog(U.mean(axis=0),S.mean(axis=0),'.');

# %%
sc.pp.neighbors(adata)
sc.tl.umap(adata)
# Out:
# WARNING: You’re trying to run this on 18255 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
sc.pl.umap(adata,color=['Piwil1', 'Tex21','Tnp1','Cldn11', 'Fabp3'])

# %%
data = adata

# %%
sc.pp.highly_variable_genes(data,n_top_genes=1000,flavor="seurat_v3")
gene_mask = (data.var_names.isin(['Piwil1', 'Tex21','Tnp1'])) | (data.var['highly_variable']) & (data.layers["unspliced"].toarray().mean(axis=0) > 0.5) & (data.layers["spliced"].toarray().mean(axis=0) > 0.5)
fitted_genes = data.var_names[gene_mask]
print(np.sort(fitted_genes))
# Out:
# ['1110065P20Rik' '1700001J03Rik' '1700001O22Rik' '1700003F12Rik'
#  '1700015E13Rik' '1700016H13Rik' '1700019N19Rik' '1700093K21Rik'
#  '4930503B20Rik' '4933411K16Rik' 'AA467197' 'Actb' 'Actg1' 'Btg1' 'Calr'
#  'Ccdc169' 'Ccser2' 'Cep85l' 'Chn2' 'Clip4' 'Cox8c' 'Creb3l4' 'Ddt'
#  'Dgat2' 'Dnah8' 'Dusp13' 'Eif5' 'Eif5a' 'Fam209' 'Fam229a' 'Fbxw5'
#  'Gapdhs' 'Habp4' 'Hook1' 'Hsp90aa1' 'Iqcf3' 'Kctd16' 'March11' 'Piwil1'
#  'Ppp3r2' 'Prm2' 'Prm3' 'Scamp1' 'Slc16a7' 'Smpd5' 'Sox5' 'Spaca9' 'Spcs2'
#  'Sub1' 'Tex21' 'Tex36' 'Tfam' 'Tnp1' 'Tnp2' 'Tomm22' 'Tor1aip1' 'Trim36'
#  'Tssk3' 'Txndc2' 'Ube2s' 'Ybx2' 'Znrf4']

# %% [markdown]
# marker genes: Piwil1 (spermatocytes), Tex21 (round spermatids), Tnp1 (elongating spermatids), Cldn11 (Sertoli cells) and Fabp3 (Leydig cells).
#
# ![image.png](attachment:image.png)

# %%
marker_genes = ['Piwil1', 'Tex21','Tnp1','Cldn11', 'Fabp3']
plot_idx = np.arange(len(fitted_genes))[fitted_genes.isin(marker_genes)]
fitted_genes[plot_idx]
# Out:
# Index(['Tnp1', 'Piwil1', 'Tex21'], dtype='object')

# %%
X = np.zeros((data.X.shape[0],np.sum(gene_mask),2))
X[:,:,0] = data.layers["unspliced"].toarray()[:,gene_mask]
X[:,:,1] = data.layers["spliced"].toarray()[:,gene_mask]
X.shape
# Out:
# (3000, 62, 2)

# %%
topo = np.array([[0,1]])
tau = (0,1,2)
traj = Trajectory(topo, tau, model="two_species_ss",verbose=1)
traj = traj.fit(X,epoch=100,parallel=True,n_threads=4)
# Out:
# run method fit_multi_init
# trial 1
#  52%|█████▏    | 52/100 [00:22<00:20,  2.36it/s]
# 100%|██████████| 100/100 [00:28<00:00,  3.56it/s]
#  18%|█▊        | 18/100 [00:09<00:43,  1.87it/s]
#  57%|█████▋    | 57/100 [00:20<00:15,  2.74it/s]
#  89%|████████▉ | 89/100 [00:36<00:04,  2.42it/s]
#  46%|████▌     | 46/100 [00:16<00:19,  2.76it/s]
# trial 2
#  48%|████▊     | 48/100 [00:21<00:22,  2.28it/s]
#  27%|██▋       | 27/100 [00:10<00:29,  2.51it/s]
#  41%|████      | 41/100 [00:17<00:24,  2.36it/s]
#  23%|██▎       | 23/100 [00:11<00:37,  2.06it/s]
# 100%|██████████| 100/100 [00:39<00:00,  2.54it/s]
#  23%|██▎       | 23/100 [00:10<00:35,  2.14it/s]
# trial 3
#  52%|█████▏    | 52/100 [00:19<00:18,  2.62it/s]
#  63%|██████▎   | 63/100 [00:22<00:13,  2.81it/s]
#  73%|███████▎  | 73/100 [00:27<00:10,  2.66it/s]
#  80%|████████  | 80/100 [00:36<00:09,  2.21it/s]
#  74%|███████▍  | 74/100 [00:25<00:08,  2.95it/s]
#  36%|███▌      | 36/100 [00:14<00:25,  2.51it/s]

# %%
data.obs['t'] = traj.Q[:,0]@traj.t
sc.pl.umap(adata,color=['t'])

# %%
plot_t(traj.Q)

# %%
plt.plot(traj.Q.sum(axis=(0,1)),'.')

# %%
plot_phase(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
plot_y(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
traj.theta[plot_idx,:]
# Out:
# array([[1.69773274e-02, 1.20484557e+00, 6.23217682e-04, 5.93525500e+02,
#         1.28501121e+00],
#        [2.33587942e-02, 4.92396773e-02, 2.31148618e+00, 6.56091696e+01,
#         5.39303850e+01],
#        [4.98141946e-01, 7.79016561e-02, 3.74878585e-02, 3.95613436e+01,
#         1.11444761e+01]])

# %% [markdown]
# # cor Genes

# %%
U = adata.layers["unspliced"].toarray()
S = adata.layers["spliced"].toarray()
gene_list = select_genes(U,S,adata.var_names,mean_min=0.5,var_min=1)
len(gene_list)
# Out:
# 15

# %%
fitted_genes_mask = (data.var_names.isin(['Piwil1', 'Tex21','Tnp1'])) | (data.var_names.isin(gene_list))
fitted_genes = data.var_names[fitted_genes_mask]

u=adata.layers["unspliced"][:,fitted_genes_mask].toarray()
s=adata.layers["spliced"][:,fitted_genes_mask].toarray()
n,p=np.shape(s)
X=np.zeros((n,p,2))
X[:,:,0]=u
X[:,:,1]=s

# %%
plot_mask = fitted_genes.isin(marker_genes)
print(fitted_genes[plot_mask])
plot_idx = np.arange(len(fitted_genes))[plot_mask]
# Out:
# Index(['Tnp1', 'Piwil1', 'Tex21'], dtype='object')

# %%
tau=(0,1,2)
topo = np.array([[0,1]])
traj = Trajectory(topo, tau, model="two_species_ss",verbose=1)
traj = traj.fit(X, n_init=3, parallel=True, n_threads=4)
# Out:
# run method fit_multi_init
# trial 1
# 100%|██████████| 20/20 [00:04<00:00,  4.61it/s]
#  55%|█████▌    | 11/20 [00:02<00:02,  4.28it/s]
#  70%|███████   | 14/20 [00:02<00:01,  4.71it/s]
#  45%|████▌     | 9/20 [00:02<00:02,  4.39it/s]
#  65%|██████▌   | 13/20 [00:02<00:01,  4.57it/s]
#  75%|███████▌  | 15/20 [00:02<00:00,  5.06it/s]
# trial 2
# 100%|██████████| 20/20 [00:05<00:00,  3.92it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.47it/s]
#  90%|█████████ | 18/20 [00:04<00:00,  4.03it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.01it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.16it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.47it/s]
# trial 3
# 100%|██████████| 20/20 [00:04<00:00,  4.40it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.27it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.70it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.35it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.24it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.81it/s]

# %%
data.obs['t'] = traj.Q[:,0]@traj.t
sc.pl.umap(data,color=['t'])

# %%
plot_phase(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
plot_y(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
traj.theta[plot_idx,:]
# Out:
# array([[1.79633037e-01, 2.62581863e+00, 1.13069219e-05, 7.85202740e+01,
#         2.12563311e-03],
#        [1.71785201e-02, 4.90665037e-02, 1.08938289e+00, 1.00207417e+02,
#         6.55018862e+01],
#        [5.79513870e-01, 8.47251757e-02, 9.02663609e-02, 3.27709242e+01,
#         7.93778709e+00]])

# %%
tau=(0,1,2)
topo = np.array([[0,1]])
traj = Trajectory(topo, tau, model="two_species",verbose=1)
traj = traj.fit(X, n_init=3, parallel=True, n_threads=4)
# Out:
# run method fit_multi_init
# trial 1
# 100%|██████████| 20/20 [00:05<00:00,  3.46it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.68it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.72it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.99it/s]
# 100%|██████████| 20/20 [00:06<00:00,  3.32it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.70it/s]
# trial 2
# 100%|██████████| 20/20 [00:05<00:00,  3.51it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.88it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.62it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.87it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.39it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.14it/s]
# trial 3
# 100%|██████████| 20/20 [00:04<00:00,  4.14it/s]
#  55%|█████▌    | 11/20 [00:02<00:02,  4.04it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.27it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.83it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.05it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.45it/s]

# %%
data.obs['t'] = traj.Q[:,0]@traj.t
sc.pl.umap(data,color=['t'])

# %%
plot_phase(traj,idx=plot_idx,gene_name=fitted_genes)

# %%
plot_y(traj,idx=plot_idx,gene_name=fitted_genes)
