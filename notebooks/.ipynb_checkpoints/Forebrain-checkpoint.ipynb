# %% [markdown]
# <a href="https://colab.research.google.com/github/meichenfang/Poisson-regression/blob/main/find-weight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# plot prior
#
# course cluster
#
# one species warm start

# %% [markdown]
# # Preparation

# %%
# %cd ../RADOM

# restrict numpy to use only one core, otherwise it will use all cores when doing @
import os
os.environ["BLAS_NUM_THREADS"] = "1" 
os.environ["OPENBLAS_NUM_THREADS"] = "1" # 

from inference import Trajectory
from plotting import *

import numpy as np
import pickle
from tqdm import tqdm
import matplotlib.pyplot as plt
import copy
# Out:
# /Users/fang/OneDrive - California Institute of Technology/Caltech/Research/Pachter/Trajectory/Poisson-regression/RADOM

# %%
def select_genes(U,S,gene_names,mean_min=0.1,var_min=1):
    gene_mask = (np.mean(S,axis=0)>0) & (np.mean(U,axis=0)>0) & (np.var(S,axis=0)>0) & (np.var(U,axis=0)>0)
    s = S[:,gene_mask]
    u = U[:,gene_mask]
    gene_names = gene_names[gene_mask]
    cov = np.cov(u,s,rowvar=False)
    s_mean = np.mean(s,axis=0)
    u_mean = np.mean(u,axis=0)
    X_mean = np.append(u_mean,s_mean)
    p = s.shape[1]
    rho = cov/X_mean[:,None]/X_mean[None,:]
    rho_s = rho[p:,p:]
    rho_u = rho[:p,:p]
    rho_us = rho[:p,p:]
    s = (np.sum(rho_us)-np.sum(np.diag(rho_us)))/(p-1)/p
    genes_mask = (s_mean>mean_min) & (u_mean>mean_min) & (np.abs(np.diag(rho_us)-s)>var_min)
    return gene_names[genes_mask]

# %% [markdown]
# ## Load data

# %%
import scanpy

adata = scanpy.read('../data/hgForebrainGlut.loom')
adata.var_names_make_unique
adata
# Out:
# /Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 1720 × 32738
#     obs: 'Clusters'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
clusters = adata.obs["Clusters"]
Clusters = set(clusters)
print(Clusters)
colors20 = np.vstack((plt.cm.tab20b(np.linspace(0., 1, 20))[::2], plt.cm.tab20c(np.linspace(0, 1, 20))[1::2]))
cell_colors = colors20[np.mod(clusters, 20)]

from matplotlib.colors import LinearSegmentedColormap
cmap_cluster = LinearSegmentedColormap.from_list("my_cmap", colors20[:7], N=7)
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %%
from sklearn.decomposition import PCA

total_UMI = adata.X.toarray().sum(axis=1)

pca = PCA(n_components=2)
x = pca.fit_transform(np.log(1+adata.X/total_UMI[:,None]*np.mean(total_UMI)))
params={'r':total_UMI/np.mean(total_UMI)}

fig, ax = plt.subplots(1,1)
ax.scatter(-x[:,0],-x[:,1],c=cell_colors);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
# Out:
# /Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/sklearn/utils/validation.py:727: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(

# %% [markdown]
# # Select genes

# %%
known_marker_genes=["SOX2","SLC17A7","EOMES"]
novel_marker_genes=["CLU","FBXO32","UNC5D","SEZ6","RBFOX1"]
their_genes=["DCX","GRIA3","STMN2", "FAM64A","ELAVL4","RNASEH2B"]
marker_genes = known_marker_genes + novel_marker_genes + their_genes
marker_idx=adata.var_names.isin(marker_genes)

# %%
scanpy.pp.highly_variable_genes(adata,n_top_genes=100,flavor='seurat_v3')
idx = (adata.var_names.isin(known_marker_genes)) | (adata.var['highly_variable']) & (adata.layers["unspliced"].toarray().mean(axis=0)>0.01) & (adata.layers["spliced"].toarray().mean(axis=0)>0.01)
gene_list=adata.var_names[idx]
print(len(gene_list))

plot_mask = gene_list.isin(marker_genes)
plot_idx = np.arange(len(gene_list))[plot_mask]

gene_list[plot_mask]
# Out:
# 40
# Index(['SLC17A7', 'EOMES', 'SOX2', 'CLU', 'FBXO32', 'STMN2'], dtype='object', name='Gene')

# %%
gene_list=adata.var_names[idx]
u=adata.layers["unspliced"][:,idx].toarray()
s=adata.layers["spliced"][:,idx].toarray()
n,p=np.shape(s)
X=np.zeros((n,p,2))
X[:,:,0]=u
X[:,:,1]=s

# %%
elbos = {}

# %% [markdown]
# ## Random initialization

# %%
fig, ax = plt.subplots(1,1)
ax.scatter(-x[:,0],-x[:,1],c='grey');
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);

# %% [markdown]
# ### one species

# %%
X_one = s[:,:,None]
np.shape(X_one)

tau=(0,1,2)
topo = np.array([[0,1]])
traj = Trajectory(topo, tau, model="one_species",verbose=1)
traj = traj.fit(X_one, n_init=10, parallel=True, n_threads=4)
# Out:
# run method fit_multi_init
# trial 1
# 100%|██████████| 100/100 [00:23<00:00,  4.18it/s]
# trial 2
# 100%|██████████| 100/100 [00:19<00:00,  5.01it/s]
# trial 3
# 100%|██████████| 100/100 [00:23<00:00,  4.23it/s]
# trial 4
# 100%|██████████| 100/100 [00:23<00:00,  4.29it/s]
# trial 5
# 100%|██████████| 100/100 [00:21<00:00,  4.63it/s]
# trial 6
#  53%|█████▎    | 53/100 [00:11<00:09,  4.79it/s]
# trial 7
# 100%|██████████| 100/100 [00:21<00:00,  4.67it/s]
# trial 8
# 100%|██████████| 100/100 [00:23<00:00,  4.28it/s]
# trial 9
# 100%|██████████| 100/100 [00:25<00:00,  3.99it/s]
# trial 10
#  28%|██▊       | 28/100 [00:06<00:15,  4.57it/s]

# %%
cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

# %% [markdown]
# ### two_species_ss

# %%
tau=(0,1,2)
topo = np.array([[0,1]])
traj = Trajectory(topo, tau,  model="two_species_ss", restrictions={}, verbose=1)
traj = traj.fit(X, n_init=10, parallel=True, n_threads=4)
# Out:
# run method fit_multi_init
# trial 1
#  42%|████▏     | 42/100 [00:10<00:14,  4.13it/s]
# trial 2
#  47%|████▋     | 47/100 [00:11<00:13,  3.97it/s]
# trial 3
# 100%|██████████| 100/100 [00:24<00:00,  4.16it/s]
# trial 4
#  46%|████▌     | 46/100 [00:11<00:13,  3.93it/s]
# trial 5
#  51%|█████     | 51/100 [00:12<00:11,  4.13it/s]
# trial 6
#  79%|███████▉  | 79/100 [00:18<00:04,  4.33it/s]
# trial 7
#  29%|██▉       | 29/100 [00:07<00:18,  3.80it/s]
# trial 8
#  36%|███▌      | 36/100 [00:08<00:14,  4.40it/s]
# trial 9
#  59%|█████▉    | 59/100 [00:14<00:10,  4.01it/s]
# trial 10
#  40%|████      | 40/100 [00:09<00:14,  4.11it/s]

# %%
traj.compute_AIC(X)
# Out:
# -943498.047514614

# %%
cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

# %%
plot_y(traj, plot_idx, gene_list, cell_colors='grey')

# %%
plot_phase(traj, plot_idx, gene_list, cell_colors='grey')

# %% [markdown]
# ### two_species_ss_rd

# %%
topo = np.array([[0,1]])
tau = (0,1,2)
traj = Trajectory(topo, tau, model="two_species_ss_rd",verbose=1)
traj = traj.fit(X,params=params,m=100,n_init=10,epoch=100,parallel=True,n_threads=4,seed=2019)
# Out:
# run method fit_multi_init
# trial 1
#  72%|██████████████████████████████▏           | 72/100 [00:54<00:21,  1.33it/s]
# trial 2
#  31%|█████████████                             | 31/100 [00:26<00:55,  1.24it/s]Process SpawnPoolWorker-609:
# Traceback (most recent call last):
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/fang/OneDrive - California Institute of Technology/Caltech/Research/Pachter/Trajectory/Poisson-regression/RADOM/models/two_species_ss_rd.py", line 14, in <module>
#     import numpy as np
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/numpy/__init__.py", line 159, in <module>
#     from . import fft
#  31%|█████████████                             | 31/100 [00:26<00:59,  1.16it/s]
# a3/envs/python_3.8/lib/python3.8/site-packages/numpy/fft/__init__.py", line 203, in <module>
#     from . import _pocketfft, helper
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 839, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 971, in get_code
#   File "<frozen importlib._bootstrap_external>", line 640, in _compile_bytecode
# KeyboardInterrupt
# Process SpawnPoolWorker-612:
# Traceback (most recent call last):
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/fang/OneDrive - California Institute of Technology/Caltech/Research/Pachter/Trajectory/Poisson-regression/RADOM/models/two_species_ss_rd.py", line 14, in <module>
#     import numpy as np
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/numpy/__init__.py", line 153, in <module>
#     from . import lib
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/numpy/lib/__init__.py", line 25, in <module>
#     from .index_tricks import *
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/numpy/lib/index_tricks.py", line 12, in <module>
#     import numpy.matrixlib as matrixlib
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/numpy/matrixlib/__init__.py", line 4, in <module>
#     from .defmatrix import *
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 914, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1407, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1379, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1510, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1553, in _fill_cache
# KeyboardInterrupt
# Process SpawnPoolWorker-610:
# Traceback (most recent call last):
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/queues.py", line 358, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/fang/OneDrive - California Institute of Technology/Caltech/Research/Pachter/Trajectory/Poisson-regression/RADOM/models/two_species_ss_rd.py", line 14, in <module>
#     import numpy as np
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/numpy/__init__.py", line 153, in <module>
#     from . import lib
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/numpy/lib/__init__.py", line 27, in <module>
#     from .nanfunctions import *
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/numpy/lib/nanfunctions.py", line 863, in <module>
#     def nanmean(a, axis=None, dtype=None, out=None, keepdims=np._NoValue):
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/numpy/core/overrides.py", line 185, in decorator
#     verify_matching_signatures(implementation, dispatcher)
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/numpy/core/overrides.py", line 92, in verify_matching_signatures
#     dispatcher_spec = ArgSpec(*getargspec(dispatcher))
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/numpy/compat/_inspect.py", line 110, in getargspec
#     args, varargs, varkw = getargs(func.__code__)
#   File "/Users/fang/opt/anaconda3/envs/python_3.8/lib/python3.8/site-packages/numpy/compat/_inspect.py", line 85, in getargs
#     if args[i][:1] in ['', '.']:
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/q7/4fq0352n3mqcb2pfnl__l8jr0000gn/T/ipykernel_18855/574908458.py in <cell line: 4>()
#       2 tau = (0,1,2)
#       3 traj = Trajectory(topo, tau, model="two_species_ss_rd",verbose=1)
# ----> 4 traj = traj.fit(X,params=params,m=100,n_init=10,epoch=100,parallel=True,n_threads=4,seed=2019)
#
# ~/OneDrive - California Institute of Technology/Caltech/Research/Pachter/Trajectory/Poisson-regression/RADOM/inference.py in fit(self, X, Q, theta, prior, params, model_restrictions, m, n_init, perm_theta, epoch, tol, parallel, n_threads, seed)
#     483             if bool(self.verbose):
#     484                 print("run method fit_multi_init")
# --> 485             res = self.fit_multi_init(X, n_init=n_init, perm_theta=perm_theta, epoch=epoch, tol=tol, parallel=parallel, n_threads=n_threads, seed=seed)
#     486
#     487         Q, elbos = res
#
# ~/OneDrive - California Institute of Technology/Caltech/Research/Pachter/Trajectory/Poisson-regression/RADOM/inference.py in fit_multi_init(self, X, n_init, perm_theta, epoch, tol, parallel, n_threads, seed)
#     359             Q = self._initialize_Q(n)
#     360             self.update_theta(X,Q,parallel=parallel,n_threads=n_threads)
# --> 361             Q, lower_bound = self._fit(X, self.theta, epoch, tol, parallel, n_threads)
#     362             theta0 = self.theta.copy()
#     363
#
# ~/OneDrive - California Institute of Technology/Caltech/Research/Pachter/Trajectory/Poisson-regression/RADOM/inference.py in _fit(self, X, theta, epoch, tol, parallel, n_threads)
#     254
#     255             ### M step
# --> 256             self.update_theta(X,Q,parallel=parallel,n_threads=n_threads) ### M step
#     257             self.update_global_time_scale(X)
#     258             #self.theta_hist.append(self.theta.copy())
#
# ~/OneDrive - California Institute of Technology/Caltech/Research/Pachter/Trajectory/Poisson-regression/RADOM/inference.py in update_theta(self, X, Q, gene_idx, parallel, n_threads)
#     115                     Input_args.append((self.theta[j], X[:,j], Q, self.t, self.tau, self.topo, self.params))
#     116             with Pool(n_threads) as pool:
# --> 117                 new_theta = pool.starmap(self.update_theta_j, Input_args)
#     118             new_theta = np.array(new_theta)
#     119         else:
#
# ~/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/pool.py in starmap(self, func, iterable, chunksize)
#     370         `func` and (a, b) becomes func(a, b).
#     371         '''
# --> 372         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     373
#     374     def starmap_async(self, func, iterable, chunksize=None, callback=None,
#
# ~/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~/opt/anaconda3/envs/python_3.8/lib/python3.8/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~/opt/anaconda3/envs/python_3.8/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~/opt/anaconda3/envs/python_3.8/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap='Blues');
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

# %% [markdown]
# ### two_species

# %% [markdown]
# #### Trials

# %%
topo = np.array([[0,1]])
tau = (0,1,2)
traj = Trajectory(topo, tau, model="two_species",verbose=0)
traj = traj.fit(X,m=100,n_init=10,epoch=100,parallel=True,n_threads=4,seed=2019)

cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

elbos['r2019'] = traj.elbos[np.argmax([traj.elbos[i][-1] for i in range(len(traj.elbos))])]

# %%
topo = np.array([[0,1]])
tau = (0,1,2)
traj = Trajectory(topo, tau, model="two_species",verbose=0)
traj = traj.fit(X,m=100,n_init=10,epoch=100,parallel=True,n_threads=4,seed=2020)

cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

elbos['r2020'] = traj.elbos[np.argmax([traj.elbos[i][-1] for i in range(len(traj.elbos))])]

# %%
topo = np.array([[0,1]])
tau = (0,1,2)
traj = Trajectory(topo, tau, model="two_species",verbose=0)
traj = traj.fit(X,m=100,n_init=10,epoch=100,parallel=True,n_threads=4,seed=2021)

cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

elbos['r2021'] = traj.elbos[np.argmax([traj.elbos[i][-1] for i in range(len(traj.elbos))])]

# %%
topo = np.array([[0,1]])
tau = (0,1,2)
traj = Trajectory(topo, tau, model="two_species",verbose=0)
traj = traj.fit(X,m=100,n_init=10,epoch=100,parallel=True,n_threads=4,seed=2022)

cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

elbos['r2022'] = traj.elbos[np.argmax([traj.elbos[i][-1] for i in range(len(traj.elbos))])]

# %%
tau=(0,1,2)
topo = np.array([[0,1]])
traj = Trajectory(topo, tau,  model="two_species", restrictions={}, verbose=0)
traj = traj.fit(X, n_init=10, parallel=True, epoch=100, n_threads=4, seed=2023)

cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

elbos['r2023'] = traj.elbos[np.argmax([traj.elbos[i][-1] for i in range(len(traj.elbos))])]

# %%
tau=(0,1,2)
topo = np.array([[0,1]])
traj = Trajectory(topo, tau,  model="two_species", restrictions={}, verbose=0)
traj = traj.fit(X, n_init=10, parallel=True, epoch=100, n_threads=4, seed=2024)

cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

elbos['r2024'] = traj.elbos[np.argmax([traj.elbos[i][-1] for i in range(len(traj.elbos))])]

# %%
tau=(0,1,2)
topo = np.array([[0,1]])
traj = Trajectory(topo, tau,  model="two_species", restrictions={}, verbose=0)
traj = traj.fit(X, n_init=10, parallel=True, epoch=100, n_threads=4, seed=2025)

cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

elbos['r2025'] = traj.elbos[np.argmax([traj.elbos[i][-1] for i in range(len(traj.elbos))])]

# %%
tau=(0,1,2)
topo = np.array([[0,1]])
traj = Trajectory(topo, tau,  model="two_species", restrictions={}, verbose=0)
traj = traj.fit(X, n_init=10, parallel=True, epoch=100, n_threads=4, seed=2026)

cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

elbos['r2026'] = traj.elbos[np.argmax([traj.elbos[i][-1] for i in range(len(traj.elbos))])]

# %%
tau=(0,1,2)
topo = np.array([[0,1]])
for seed in tqdm(range(2027,2030)):
    traj = Trajectory(topo, tau,  model="two_species", restrictions={}, verbose=0)
    traj = traj.fit(X, n_init=10, parallel=True, epoch=100, n_threads=4, seed=seed)

    cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
    fig, ax = plt.subplots(1,1)
    im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
    ax.set_xlabel('PC1',fontsize=24)
    ax.set_ylabel('PC2',fontsize=24)
    ax.set_frame_on(False)
    plt.xticks([]);
    plt.yticks([]);
    plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right
    plt.title(seed)

    elbos['r'+str(seed)] = traj.elbos[np.argmax([traj.elbos[i][-1] for i in range(len(traj.elbos))])]
# Out:
# 100%|██████████| 3/3 [08:12<00:00, 164.04s/it]

# %% [markdown]
# #### ELBOs

# %%
for idx in np.sort(list(elbos.keys())):
    print(idx, elbos[idx][-1])
# Out:
# cc 275.1110995091566
# cf 275.0248826167076
# r2019 274.4441158485346
# r2020 274.4476628001356
# r2021 274.1619679556389
# r2022 274.4933403512633
# r2023 275.0715989691229
# r2024 275.53461292917984
# r2025 274.7668235157177
# r2026 274.8740670729918
# r2027 275.7957509610295
# r2028 275.4051129083133
# r2029 274.6938896256205
# r42 275.0062577142856
# r43 274.85080561030844

# %%
fig, ax = plt.subplots(1,1)
ax.plot(elbos['r2019'],label="random init 2019",linewidth=1,alpha=0.5);
ax.plot(elbos['r2020'],label="random init 2020",linewidth=1,alpha=0.5);
ax.plot(elbos['r2021'],label="random init 2021",linewidth=1,alpha=0.5);
ax.plot(elbos['r2022'],label="random init 2022",linewidth=1,alpha=0.5);
ax.plot(elbos['r2023'],label="random init 2023",linewidth=1,alpha=0.5);
ax.plot(elbos['r2024'],label="random init 2024",linewidth=1,alpha=0.5);
ax.set_yscale('log')
ax.set_xlabel('epoch',fontsize=18)
ax.set_ylabel('relative elbo',fontsize=18)
plt.legend(fontsize=18);
ax.axes.get_yaxis().set_visible(False)

# %%
traj = Trajectory(topo, tau,  model="two_species", restrictions={}, verbose=1)
traj = traj.fit(X, n_init=10, parallel=True, epoch=100, n_threads=4, seed=2027)
# Out:
# run method fit_multi_init
# trial 1
# 100%|██████████| 100/100 [00:32<00:00,  3.06it/s]
# trial 2
#  46%|████▌     | 46/100 [00:14<00:16,  3.19it/s]
# trial 3
#  20%|██        | 20/100 [00:07<00:30,  2.66it/s]
# trial 4
#  59%|█████▉    | 59/100 [00:19<00:13,  3.08it/s]
# trial 5
#  46%|████▌     | 46/100 [00:14<00:16,  3.18it/s]
# trial 6
#  34%|███▍      | 34/100 [00:11<00:22,  2.95it/s]
# trial 7
#  46%|████▌     | 46/100 [00:14<00:17,  3.13it/s]
# trial 8
#  49%|████▉     | 49/100 [00:15<00:15,  3.26it/s]
# trial 9
#  38%|███▊      | 38/100 [00:11<00:19,  3.18it/s]
# trial 10
#  26%|██▌       | 26/100 [00:08<00:24,  2.99it/s]

# %% [markdown]
# #### Pick the highest one and plot Q

# %%
ax = plot_t(traj.Q[order],l=0,order_cells=False)
x_label_list = ['0', '1', '2']
ax.set_xticks([0,50,100])
ax.set_xticklabels(x_label_list)
ax.set_yticks([])
# Out:
# []

# %%
order = np.argsort(traj.Q[:,0]@traj.t)
cluster = np.zeros(adata.n_obs)
for i,cell_type in enumerate(Clusters):
    idx = adata.obs["Clusters"].isin([cell_type])
    cluster[idx] = i
#plt.scatter(np.sum(t_grids[None,:]*weight0,axis=1),s,c=colors20[np.mod(clusters, 20)]);
fig, ax = plt.subplots(1,1,figsize=(0.5,4))
ax.imshow(cluster[order,None],aspect="auto",cmap=cmap_cluster)
ax.set_xticks([])
# Out:
# []

# %%
ax = plot_t(traj.Q[order],l=0,order_cells=False)
x_label_list = ['0', '1', '2']
ax.set_xticks([0,50,100])
ax.set_xticklabels(x_label_list)
ax.set_yticks([])
# Out:
# []

# %%
plot_phase(traj, plot_idx, gene_list, cell_colors='grey')

# %%
plot_y(traj, plot_idx, gene_list, cell_colors='grey')

# %% [markdown]
# ## Fine clusters

# %%
print(Clusters)
m=100
t_grids=np.linspace(0,2,m)
weight0 = np.ones((adata.n_obs,m))
for i in Clusters:
    idx = clusters.isin([i])
    weight0[idx,int(i*m/7):int((i+1)*m/7)] += 1
weight0=weight0/weight0.sum(axis=1,keepdims=True)
#plt.scatter(np.sum(t_grids[None,:]*weight0,axis=1),s,c=colors20[np.mod(clusters, 20)]);
Q0 = weight0[:,None]
ax = plot_t(Q0,order_cells=True)

x_label_list = ['0', '1', '2']
ax.set_xticks([0,50,100])
ax.set_xticklabels(x_label_list)

label_font = '24'
plt.ylabel("cells", fontsize = label_font);
plt.xlabel("time grids", fontsize = label_font);
# Out:
# {0, 1, 2, 3, 4, 5, 6}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/q7/4fq0352n3mqcb2pfnl__l8jr0000gn/T/ipykernel_18855/522418621.py in <cell line: 11>()
#       9 #plt.scatter(np.sum(t_grids[None,:]*weight0,axis=1),s,c=colors20[np.mod(clusters, 20)]);
#      10 Q0 = weight0[:,None]
# ---> 11 ax = plot_t(Q0,order_cells=True)
#      12
#      13 x_label_list = ['0', '1', '2']
#
# ~/OneDrive - California Institute of Technology/Caltech/Research/Pachter/Trajectory/Poisson-regression/RADOM/plotting.py in plot_t(traj, l, ax, t, order_cells)
#      31
#      32 def plot_t(traj,l=0,ax=None,t=None,order_cells=False):
# ---> 33     t_hat=traj.Q[:,l]@traj.t
#      34     if ax is None:
#      35         fig, ax = plt.subplots(1,1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'Q'

# %%
tau=(0,1,2)
topo = np.array([[0,1]])
traj = Trajectory(topo, tau,  model="two_species", restrictions={}, verbose=1)
traj = traj.fit(X, Q=Q0, parallel=True, n_threads=2)
# Out:
# run method fit_warm_start
#  79%|███████▉  | 79/100 [00:26<00:07,  2.93it/s]

# %%
traj.elbos[-1]
# Out:
# 275.0248826167076

# %%
elbos['cf'] = traj.elbos

# %%
cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

# %%
plot_phase(traj, plot_idx, gene_list, cell_colors='grey')

# %%
order = np.argsort(traj.Q[:,0]@traj.t)
cluster = np.zeros(adata.n_obs)
for i,cell_type in enumerate(Clusters):
    idx = adata.obs["Clusters"].isin([cell_type])
    cluster[idx] = i
#plt.scatter(np.sum(t_grids[None,:]*weight0,axis=1),s,c=colors20[np.mod(clusters, 20)]);
fig, ax = plt.subplots(1,1,figsize=(0.5,4))
ax.imshow(cluster[order,None],aspect="auto",cmap=cmap_cluster)
ax.set_xticks([])
# Out:
# []

# %%
ax = plot_t(traj.Q[order],l=0,order_cells=False)
x_label_list = ['0', '1', '2']
ax.set_xticks([0,50,100])
ax.set_xticklabels(x_label_list)
ax.set_yticks([])
# Out:
# []

# %% [markdown]
# ## Coarse clusters

# %%
Clusters_c = [[0,1],[2,3],[4,5],[6]]
print(Clusters_c)
m=100
t_grids=np.linspace(0,2,m)
weight0 = np.ones((adata.n_obs,m))
for i,cell_type in enumerate(Clusters_c):
    idx = clusters.isin(cell_type)
    weight0[idx,int(i*m/4):int((i+1)*m/4)] += 1
weight0=weight0/weight0.sum(axis=1,keepdims=True)
#plt.scatter(np.sum(t_grids[None,:]*weight0,axis=1),s,c=colors20[np.mod(clusters, 20)]);
Q0 = weight0[:,None]
ax = plot_t(Q0,order_cells=True)

x_label_list = ['0', '1', '2']
ax.set_xticks([0,50,100])
ax.set_xticklabels(x_label_list)

label_font = '24'
plt.ylabel("cells", fontsize = label_font);
plt.xlabel("time grids", fontsize = label_font);
# Out:
# [[0, 1], [2, 3], [4, 5], [6]]

# %%
fig, ax = plt.subplots(1,1)
Clusters_c = [[0,1],[2,3],[4,5],[6]]
for i,cell_type in enumerate(Clusters_c):
    idx = clusters.isin(cell_type)
    if i ==3:
        ax.scatter(-x[idx,0],-x[idx,1],c=colors20[i*2]);
    else:
        ax.scatter(-x[idx,0],-x[idx,1],c=(colors20[i*2]+colors20[i*2+1])/2);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
tau=(0,1,2)
topo = np.array([[0,1]])
traj = Trajectory(topo, tau,  model="two_species", restrictions={}, verbose=1)
traj = traj.fit(X, Q=Q0, parallel=True, n_threads=2)
# Out:
# run method fit_warm_start
#  19%|█▉        | 19/100 [00:09<00:38,  2.08it/s]

# %%
cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

# %%
traj.compute_AIC(X)
# Out:
# -945902.1823114987

# %%
elbos['cc'] = traj.elbos

# %%
for idx in elbos.keys():
    print(idx, elbos[idx][-1])
# Out:
# r2019 274.4441158485346
# r2020 274.4476628001356
# r2021 274.1619679556389
# r2022 274.4933403512633
# r2023 275.0715989691229
# r2024 275.53461292917984
# cf 275.0248826167076
# cc 275.1110995091566

# %%
order = np.argsort(traj.Q[:,0]@traj.t)
cluster = np.zeros(adata.n_obs)
for i,cell_type in enumerate(Clusters):
    idx = adata.obs["Clusters"].isin([cell_type])
    cluster[idx] = i
#plt.scatter(np.sum(t_grids[None,:]*weight0,axis=1),s,c=colors20[np.mod(clusters, 20)]);
fig, ax = plt.subplots(1,1,figsize=(0.5,4))
ax.imshow(cluster[order,None],aspect="auto",cmap=cmap_cluster)
ax.set_xticks([])
# Out:
# []

# %%
fig, ax = plt.subplots(1,1,figsize=(6,4))
ax=plot_t(traj.Q[order],l=0,ax=ax,order_cells=False)
ax.set_yticks([]);

# %%
plot_mask = gene_list.isin(known_marker_genes)
plot_idx = np.arange(len(gene_list))[plot_mask]

gene_list[plot_mask]

plot_phase(traj, plot_idx, gene_list, cell_colors='grey')

plot_y(traj, plot_idx, gene_list, cell_colors='grey')

# %%
plot_mask = gene_list.isin(novel_marker_genes)
plot_idx = np.arange(len(gene_list))[plot_mask]

gene_list[plot_mask]

plot_phase(traj, plot_idx, gene_list, cell_colors='grey')

plot_y(traj, plot_idx, gene_list, cell_colors='grey')

# %%
plot_mask = gene_list.isin(their_genes)
plot_idx = np.arange(len(gene_list))[plot_mask]

gene_list[plot_mask]

plot_phase(traj, plot_idx, gene_list, cell_colors='grey')

plot_y(traj, plot_idx, gene_list, cell_colors='grey')

# %%
plot_mask = gene_list.isin(marker_genes)
plot_idx = np.arange(len(gene_list))[plot_mask]

fig,ax = plt.subplots(1,1)
for j in range(p):
    ax.plot([0,1,2],traj.theta[j,[-3,0,1]],'-*',color='gray')
for j in plot_idx:
    ax.plot([0,1,2],(traj.theta[j,-3],traj.theta[j,0],traj.theta[j,1]),'-*',color='red')

x_label_list = ['u0', 'α1', 'α2']
ax.set_xticks([0,1,2])
ax.set_xticklabels(x_label_list)
plt.yscale('log')

# %% [markdown]
# ## ELBO plot

# %%
fig, ax = plt.subplots(1,1)
ax.plot(elbos['r'],label="random init",linewidth=6,alpha=0.5);
ax.plot(elbos['cf'],label="fine clusters",linewidth=6,alpha=0.5);
ax.plot(elbos['cc'],label="coarse clusters",linewidth=6,alpha=0.5);
ax.set_yscale('log')
ax.set_xlabel('epoch',fontsize=18)
ax.set_ylabel('relative elbo',fontsize=18)
plt.legend(fontsize=18);
ax.axes.get_yaxis().set_visible(False)

# %% [markdown]
# # Marker genes only

# %%
idx = adata.var_names.isin(marker_genes)
u=adata.layers["unspliced"][:,idx].toarray()
s=adata.layers["spliced"][:,idx].toarray()
n,p=np.shape(s)
X=np.zeros((n,p,2))
X[:,:,0]=u
X[:,:,1]=s

# %%
topo = np.array([[0,1]])
tau = (0,1,2)
traj = Trajectory(topo, tau, model="two_species_ss",verbose=0)
traj = traj.fit(X,m=100,n_init=10,epoch=100,parallel=True,n_threads=4,seed=2019)
print(-traj.compute_AIC(X)/2/len(X))

cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

elbos['r2019'] = traj.elbos[np.argmax([traj.elbos[i][-1] for i in range(len(traj.elbos))])]
# Out:
# 103.12844592467029

# %%
topo = np.array([[0,1]])
tau = (0,1,2)
traj = Trajectory(topo, tau, model="two_species",verbose=0)
traj = traj.fit(X,m=100,n_init=10,epoch=100,parallel=True,n_threads=4,seed=2019)
print(-traj.compute_AIC(X)/2/len(X))

cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
fig, ax = plt.subplots(1,1)
im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
ax.set_xlabel('PC1',fontsize=24)
ax.set_ylabel('PC2',fontsize=24)
ax.set_frame_on(False)
plt.xticks([]);
plt.yticks([]);
plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right

elbos['r2019'] = traj.elbos[np.argmax([traj.elbos[i][-1] for i in range(len(traj.elbos))])]

# %%
print(-traj.compute_AIC(X)/2/len(X))
# Out:
# 103.21728197924303

# %%
tau=(0,1,2)
topo = np.array([[0,1]])
for seed in tqdm(range(2020,2030)):
    traj = Trajectory(topo, tau,  model="two_species", restrictions={}, verbose=0)
    traj = traj.fit(X, n_init=10, parallel=True, epoch=100, n_threads=4, seed=seed)

    cmap_y = cmr.get_sub_cmap('Blues', 0.2, 1)
    fig, ax = plt.subplots(1,1)
    im=ax.scatter(-x[:,0],-x[:,1],c=traj.Q[:,0]@traj.t,cmap=cmap_y);
    ax.set_xlabel('PC1',fontsize=24)
    ax.set_ylabel('PC2',fontsize=24)
    ax.set_frame_on(False)
    plt.xticks([]);
    plt.yticks([]);
    plt.colorbar(im,fraction=0.05, shrink =0.9) # adding the colobar on the right
    plt.title(seed)

    print( traj.elbos[np.argmax([traj.elbos[i][-1] for i in range(len(traj.elbos))])] )
# Out:
#  10%|█         | 1/10 [01:03<09:31, 63.52s/it]
# [70.19374232533414, 71.64919121251297, 99.96275505773265, 102.5479879442843, 102.98275084276506, 103.09824066995454, 103.12139352241235, 103.13238512344242, 103.13929660564833, 103.16541617187177, 103.17181590845321, 103.17701152797282, 103.18601362425439, 103.1905541209241, 103.19413807287654, 103.20094007482919, 103.20389388139681, 103.21049409607726, 103.21213313523019, 103.21350671712712, 103.21509418036081, 103.21616998483037, 103.21703951673618, 103.22220008477635, 103.22373793184924, 103.2250183107704, 103.2258068604369, 103.2268925070795, 103.2274081650335, 103.22789178736285, 103.22822450014023, 103.22847393394572, 103.22865537712151, 103.23134431742285, 103.23183163408086, 103.23206393072081, 103.23217727739095, 103.2322513327907]
#  20%|██        | 2/10 [02:14<09:01, 67.69s/it]
